# %%
import pandas as pd

# %%
file_path = 'C:\\Users\\ARPIT DIMRI\\OneDrive\\Desktop\\Premiere-League-pred-model\\data\\premier-league-matches.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#    Season_End_Year  Wk        Date            Home  HomeGoals  AwayGoals  \
# 0             1993   1  1992-08-15   Coventry City          2          1
# 1             1993   1  1992-08-15    Leeds United          2          1
# 2             1993   1  1992-08-15   Sheffield Utd          2          1
# 3             1993   1  1992-08-15  Crystal Palace          3          3
# 4             1993   1  1992-08-15         Arsenal          2          4
#
#              Away FTR
# 0   Middlesbrough   H
# 1       Wimbledon   H
# 2  Manchester Utd   H
# 3       Blackburn   D
# 4    Norwich City   A

# %%
print(df.shape)
df.head()
df.dtypes
df.isnull().sum()
# Out:
# (12026, 8)
# Season_End_Year    0
# Wk                 0
# Date               0
# Home               0
# HomeGoals          0
# AwayGoals          0
# Away               0
# FTR                0
# dtype: int64

# %%
#converting date column to datetime format and sorting the data by date
f['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date').reset_index(drop=True)

# %%
#Clean result column
df['result'] = df['FTR'].map({
    'H': 'Home Win',
    'D': 'Draw',
    'A': 'Away Win'
})

# %%
#checking for the null values
df.isnull().sum()
# Out:
# Season_End_Year    0
# Wk                 0
# Date               0
# Home               0
# HomeGoals          0
# AwayGoals          0
# Away               0
# FTR                0
# result             0
# dtype: int64

# %%
#for dropping null values
df = df.dropna()

# %%
#removinng duplicates 
df = df.drop_duplicates()

# %%
#sanity check
print(df['result'].value_counts())
print(df['Season_End_Year'].unique())

#Asks:
#Does distribution make sense
#Any wierd values in the data
# Out:
# result
# Home Win    5519
# Away Win    3410
# Draw        3097
# Name: count, dtype: int64
# [1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006
#  2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020
#  2021 2022 2023]

# %%
#Saving clean data to a new csv file
df.to_csv('C:\\Users\\ARPIT DIMRI\\OneDrive\\Desktop\\Premiere-League-pred-model\\data\\processed_data.csv', index=False)
